# %% [markdown]
# <p align="center">
# <a href="https://github.com/jina-ai/dalle"><img src="https://github.com/jina-ai/dalle-flow/blob/main/.github/banner.svg?raw=true" alt="DALL·E Flow: A Human-in-the-Loop workflow for creating HD images from text" width="60%"></a>
# <br>
# </p>
#
#
# <b>A Human-in-the-Loop<sup><a href="https://en.wikipedia.org/wiki/Human-in-the-loop">?</a></sup> workflow for creating HD images from text</b>

# %% [markdown]
# [![GitHub Repo stars](https://img.shields.io/github/stars/jina-ai/dalle-flow?style=social)](https://github.com/jina-ai/dalle-flow) [![Google Colab](https://img.shields.io/badge/Slack-2.8k-blueviolet?logo=slack&amp;logoColor=white&style=flat-square)](https://slack.jina.ai) [![GitHub last commit (branch)](https://img.shields.io/github/last-commit/jina-ai/dalle-flow/main)](https://colab.research.google.com/github/jina-ai/dalle-flow/blob/main/client.ipynb)

# %% [markdown]
# 🚧 If you find your request fails, it is possible the server is occasionally down for maintaince. Please give it a try in 5 minutes.
#
# - **2022/6/3** Reduce default number of images to 2 per pathway, 4 for diffusion.
# - ⚠️ 2022/5/23 Fix an upstream bug in CLIP-as-service. This bug makes the 2nd diffusion step irrelevant to the given texts. New Dockerfile proved to be reproducible on a AWS EC2 `p2.x8large` instance.
# - 2022/5/13b Removing TLS as Cloudflare gives 100s timeout, making DALLE Flow in usable [Please _reopen_ the notebook in Google Colab!](https://colab.research.google.com/github/jina-ai/dalle-flow/blob/main/client.ipynb).
# - 🔐 2022/5/13 New Mega checkpoint! All connections are now with TLS, [Please _reopen_ the notebook in Google Colab!](https://colab.research.google.com/github/jina-ai/dalle-flow/blob/main/client.ipynb).
# - 🌟 2022/5/10 [A Dockerfile is added! Now you can easily deploy your own DALL·E Flow](https://github.com/jina-ai/dalle-flow). New Mega checkpoint! Smaller memory-footprint, the whole Flow can now fit into **one GPU with 21GB memory**.
# - 🌟 2022/5/9 Less memory-footprint overall, the whole Flow can now fit into one GPU with 18GB memory!
# - 🌟 2022/5/7 DALL·E Flow just got updated!
#     - New DALL·E Mega checkpoint
#     - Improved GLID3 memory-efficiency and parameters
# - 🌟 2022/5/6 DALL·E Flow just got updated!
#     - The first step will generate 16 candidates: **8 from DALL·E Mega, 8 from GLID3-XL**; ranked by CLIP-as-service.
#     - Optimized the flow efficiency, diffusion and upscaling is much faster now!
# - ~~⚠️ 2022/5/3 **The number of images is restrict to 9 for DALL·E Mega, and 16 for GLID3-XL**~~
# - ⚠️ 2022/5/2 **Due to the massive requests now, the server is super busy.** You can deploy your own server by following [the instruction here](https://github.com/jina-ai/dalle-flow#server).

# %% [markdown]
# Using client is super easy. The following steps are best run in Jupyter notebook or [Google Colab](https://colab.research.google.com/github/jina-ai/dalle-flow/blob/main/client.ipynb).
#
# The only dependency you will need are [DocArray](https://github.com/jina-ai/docarray) and [Jina](https://github.com/jina-ai/jina), as DocArray is already included in Jina you only need to install `jina`.
#
# > On Google Colab, you will be asked to restart the kernel. Go ahead and restart.

# %%
# !pip install jina
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jina in /usr/local/lib/python3.7/dist-packages (3.6.2)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.7/dist-packages (from jina) (0.0.5)
# Requirement already satisfied: grpcio-health-checking>=1.46.0 in /usr/local/lib/python3.7/dist-packages (from jina) (1.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from jina) (3.7.0)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.7/dist-packages (from jina) (0.16.0)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.7/dist-packages (from jina) (0.17.6)
# Requirement already satisfied: fastapi>=0.76.0 in /usr/local/lib/python3.7/dist-packages (from jina) (0.78.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from jina) (37.0.2)
# Requirement already satisfied: docker in /usr/local/lib/python3.7/dist-packages (from jina) (5.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from jina) (2.23.0)
# Requirement already satisfied: aiostream in /usr/local/lib/python3.7/dist-packages (from jina) (0.4.4)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from jina) (6.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jina) (0.14.1)
# Requirement already satisfied: protobuf<=3.20.1,>=3.19.1 in /usr/local/lib/python3.7/dist-packages (from jina) (3.20.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from jina) (21.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from jina) (1.9.1)
# Requirement already satisfied: docarray>=0.13.14 in /usr/local/lib/python3.7/dist-packages (from jina) (0.13.21)
# Requirement already satisfied: grpcio>=1.46.0 in /usr/local/lib/python3.7/dist-packages (from jina) (1.46.3)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.7/dist-packages (from jina) (0.8.0)
# Requirement already satisfied: lz4<3.1.2 in /usr/local/lib/python3.7/dist-packages (from jina) (3.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from jina) (1.21.6)
# Requirement already satisfied: websockets in /usr/local/lib/python3.7/dist-packages (from jina) (10.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from jina) (3.8.1)
# Requirement already satisfied: pathspec in /usr/local/lib/python3.7/dist-packages (from jina) (0.9.0)
# Requirement already satisfied: grpcio-reflection>=1.46.0 in /usr/local/lib/python3.7/dist-packages (from jina) (1.46.3)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.7/dist-packages (from docarray>=0.13.14->jina) (12.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from docarray>=0.13.14->jina) (3.2.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from docarray>=0.13.14->jina) (7.1.2)
# Requirement already satisfied: starlette==0.19.1 in /usr/local/lib/python3.7/dist-packages (from fastapi>=0.76.0->jina) (0.19.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.19.1->fastapi>=0.76.0->jina) (3.6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.19.1->fastapi>=0.76.0->jina) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi>=0.76.0->jina) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi>=0.76.0->jina) (1.2.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.46.0->jina) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->jina) (3.0.9)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=12.0.0->docarray>=0.13.14->jina) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=12.0.0->docarray>=0.13.14->jina) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->jina) (21.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->jina) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->jina) (2.21)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker->jina) (1.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->jina) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->jina) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->jina) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->docarray>=0.13.14->jina) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->docarray>=0.13.14->jina) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->docarray>=0.13.14->jina) (1.4.2)
# Requirement already satisfied: asgiref>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (3.5.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (0.13.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (7.1.2)
# Requirement already satisfied: watchgod>=0.6 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (0.8.2)
# Requirement already satisfied: httptools>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]->jina) (0.20.0)

# %% [markdown]
# We have provided a demo server for you to play:

# %%
server_url = 'grpc://dalle-flow.jina.ai:51005'

# %% [markdown]
# ### Step 1: Generate via DALL·E Mega
#
# Now let's define the prompt:

# %%
prompt = 'a surfer in the game Grand theft auto five'

# %% [markdown]
# Let's submit it to the server and visualize the results:

# %%
# %%time

from docarray import Document

da = Document(text=prompt).post(server_url, parameters={'num_images': 2}).matches

da.plot_image_sprites(fig_size=(10,10), show_index=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CPU times: user 3.02 s, sys: 388 ms, total: 3.41 s
# Wall time: 6min 11s

# %% [markdown]
# Here we generate 4 candidates, 2 from DALLE-mega and 2 from GLID3 XL, this is as defined in `num_images`, which takes about ~2 minutes. You can use a smaller value if it is too long for you. The results are sorted by [CLIP-as-service](https://github.com/jina-ai/clip-as-service), with index-`0` as the best candidate judged by CLIP.

# %% [markdown]
# ### Step 2: Select and refinement via GLID3 XL
#
# Of course, you may think differently. Notice the number in the top-left corner? Select the one you like the most and get a better view:

# %%
fav_id = 3

fav = da[fav_id]

fav.display()
# Out:
#     <body>
#     <image src="data:image/png;charset=utf-8,%89PNG%0D%0A%1A%0A%00%00%00%0DIHDR%00%00%01%00%00%00%01%00%08%02%00%00%00%D3%10%3F1%00%01%00%00IDATx%9C%5C%FDY%D0l%D9r%1E%86%7D%99%B9%F6%DEU%FFt%86%9E%87%DBw%04%40%5C%80%00%01%10%24%C5%21%08R%20-2D%D2%84H1%C8%B0%18a9%EC%B0%EC%07%FA%D1%8F~%F0%83-9%24%85-%0F%B2%2C%3AB%21%D94%05Sa%87Hq%9E%20b%A0%08%90%18.%EE%DC%E8%BE%3D%9D%D3%7D%A6%7F%AA%AA%BD%D7%CA%FC%FC%90k%D79%F4%89%1B%B7%BB%FFS%7F%D5%AE5d~%F9%E5%97%99%F2%BF%FDk%FF%0F%3A%C2%04%02%25%21B%00%00%21%00D%14%24%00%F6%BF%22%09%01%08B%94%24%00%110%28%22d%20%FF%12%F9%0A%40%20%F9%EF%A4%E4%DB%8A%08IRD%80%FC%19%08J%FFEa%FF%FD%FEG%98%EF%24%04%23%90%0F%03%92%22%E8%9F.%2A%EB%3B%8B%40%08H%FFt%E4%5B%02%A0%F6OG%FF%28%E4%5B%11%10%E9O%11%E8%DFF%98%DF%13%A0%80%24%09%12%10Y%DF%8F%20%11%A1%EBo%02%22r%FC%C8%FEO%E9%0B%F0%C2%3F%84%C2%5CZ%C9%F7%3F%FEY%9F%96/%FE%E8%85wd%BE%E3%BA%AE%B2%3E%3C%09%C1%F1%A3%8F%DF._.%B9~%CF%7FO%FAn%E1%F8n%20D%FA%DB%AC%8F%C1%E3%EF%11%A0%08%18B%40%F4%F8%10B%0AD%F4%F8%E6%EB%D2%12%2A%7Dy%F3%E7%A2%CA%80%00%C1%90%FC%A4%C0%0B/%10%11%CD/%22%AA%8C%3Cc%22d.%1F%01Rr%F7s%1F%82%00%E1%11%10R%08%1A%97f%BB%FA%CA%10%FF%9F%BF%FC%7F%DD%CF%CB%E7%DE%7C%FD%CF%FFO%FF%E2%93%EB%C5%5B%E8f%FB%EC%C9U%9D%97%F0%16%80%9A%15%D3%C8%FD%05T%94%CB%5C%22DD%84%90%20%A0%20E%F3%F1%84%B9%10A%00%2A%CF%8F%DDq%D5%8Fk%29%C8%27%95%3CQ%CFO_%DFq%AEg%27%AF%97%08D%F3%3B%F5_%97%E3%9EH.z%3F%B7%C7-%87%13%96%2BC%A2%FF%9F%0A%20%90%08%8A%40%F3%96%F6%A7%A0%CA%BA%87%80%10%F9%E0%B2%EE%3A%8F%E7S%FA%25%05EU%01%0A%25%AFB%DE%F4%FC%AE%A2%DA%7F%92%7F%13%A1Zx%BC%28%20%D6%1B%99%1F%94%0Bx%3C%FCX%DF%E8%85Uz~%DA%F3%F8%89%E4%FB%F7g%5D%3F%8E%E8%07%A7%DB%9Eu%AD%C0%00DD%80x%E1%20%F6%F7%94~%3B%40%ED%27v%3Dp/%BC%8C%C7E%E6%BA%E0%0A%AEV%86B%11%01%29%14%01d5%7D%14%11%88%1C%D7V%E4%85%CF%05%00%E5%FA%3CyJ%08%80%06e%AC%1B%B7%3E%87%1E%AF%1D%A5%1B-%22%1FX%C8H%13%D0%0D%26%FBu%17%09%86%8A%40Q%83%22%11%A2%A2%A3%88%0E%9BW%96%F9%E3i%DA%16L7O%AEg%B0%DEV_ZTW%0A%89%20%C3%DB%F1%BBA%00%D9%14%D1%92K%24%D1%AF0%00Q%89n%BE%09%15%F6-%E5s%3B%A2%FDp%F4M%3E%1A%22%C9S%DE%7F%A3%3B%90%D5%AB%E4%09%20%8F%C7%EFx%D2%8F%C7A%FA%C1%CE%8F%C9c%9E%DBN%04CM%F0%C2%01%EAg%98%D2%B7J%05A%11%8Dn%03W%CFs%DC%2A%E9%CB.%00C%F2Z%CB%FAE%99%17T%A5%C4s%DB%14%11y%81%29%08%80A%01XT%40%04D4H%11%03%03%94%17%CF%97tS%DF%EF%1FI%88%82%EC%0ED%F5%F9Wf%1ES%C8z%CC%D2%A3%CA%EA%87%80%FC%18%CD%3D%10%08%83R%5Ep%0B%C7%CB%D4%CD~nKw%5B%C7%C3%29%FD2%A1%5B~%AE%FE%0E/%3C%BBF%BF%FArt%F6%0C%88v%07%2B%02%CA%FAV%CF%8F%FD%FA%EB%FDEya%F34%98%80%11L%23%2A%C2%B4M%09%03%B4%7FeE%B7%01%DD%8A%F5%CF%A0%E8z%E8%04%C7eRU%04%05%C5%24%80%90%B6%19%07D%19%86-%F4d%1A%EE%98lN%C6%CD%ED%FEj%28%DB%88J%A7%A7%95m%D1%04%AA%10%2B%0A%A1%01%C2%92%27I%21%14%E6%CD%CE%B5%D7%D5%01%F5%25%CB%13%96%D7%E6%85%CB%9F%27%ECh%06%F8%FC%D5Hw%06%5D%B1J%3Fg%82%88%A3%C9%C8U%C5%F1%3D%D7%3B%97%A6C%91%CEHE%28%E0%A0%25%9D%400%9C%8C%B4%12%EB%DEv%EF%AB%FD_W%83%D5%DD%FE%11%17%E8j%BCD%01t/v%3CW%20%841%98%0DEME%20%EE%CE%40%90%0D%0C%A6%7Dd%90%AA%12/~%05%AE%CE%01%F2%FCl%05EI%28T%8E%9F%83%20EW%1B%29%00%0C%FDp%00%94%80%88P%8F%06o%3DG%2A%22%C2%15p%880%0F%EE%FA%0Ci%93%FB.t%97%B1%1Ey%AE0%F2_%BA%0D%80%EA%BAt%3C%AE%7C76%24E%AC_Ae_%B7%D5%AAKG%2A%EB%25%EBG%01%C7%C3/G%10%26%DD%FD%AB%F4%DF%CC%D3%1E%0CQ%11Uz%3E%F9%0A%0E%F2%B7%22%84%9A%1F%84t%E5%AB%C7%0F%80%C2%80F%DF%07X%29l%10H%91a%F1%C56%13%C1%C6%99%5E%C7%E1%14%B1%D9n7u%F1%08/%FD9H%11%11%5Dj%13%93%22%DD%F9p%DD%C8%EE%B6%08%11%ED%882W%1F%D4%60%AC%CB%BDZ%F3%15%CEJGR%C7%83%8E%23%3EP%15%06D%10%F9%BB%A6%AB%E5%EAP%26%BF_%07-%FDB%A8%00%88%15%3F%08UDUUDE%04%25H%06%9DA%D2%C1D%04XO%A0B%02%89%D2D%00%5Bo%2A%8F%A70%8D%D1%0B%BF%02%81%AA%08%A8%D2%CF%93%88%A8%C2%AC0%88%00Ej%B8%87%83%08%12D%28%18%DD%D3%AD%98%5C%D8%17%8E%B2%BAS%F6%83%B2%C2%17%B5%FC%A1B%12%5E%22%F7%F5%B9%29%25%24%D1X~%F5~J%83%84H%AC~%B7%BB%EA%FE%9F%E8%90%ED9%8E%97%D5%9E%E4%03%E4%FE%AEF%3B%EF%2A%BB%0B%88%E8%8E%1F%40%BF%A0%FA%DC%9E%03x%8Ei%C8%F4%9B%8A%E7%A7_W%EF%00%01%03%22%1D%D0%AC%27%3EW%28%11%26%04%8C%08M%CB%28%22%06%81%26v%15E%A4%ABP%ED%B6%F3%18Z%E5y%93%E77%96pRL%D1%96%3A%CAP%B4%84%A3-m%D8%94%90%3A%15%BE%FD%FA%CBR%B6%CFp%D8%ED%97%B3%D3%8B%C3%FEF%A3Qs%D ...

# %% [markdown]
# Now let's submit the selected candidates to the server for diffusion.

# %%
# %%time

diffused = fav.post(f'{server_url}', parameters={'skip_rate': 0.6, 'num_images': 4}, target_executor='diffusion').matches

diffused.plot_image_sprites(fig_size=(10,10), show_index=True)

# %% [markdown]
# This will give 4 images based on the given image. You may allow the model to improvise more by giving `skip_rate` a near-zero value, or a near-one value to force its closeness to the given image. The whole procedure takes about ~1 minutes.

# %% [markdown]
# ### Step 3: Select and upscale via SwinIR
#
# Select the image you like the most, and give it a closer look:

# %%
dfav_id = 2

fav = diffused[dfav_id]

fav.display()

# %% [markdown]
# Finally, submit to the server for the last step: upscaling to 1024 x 1024px.
#
# > This step should be much faster (~10s) as the Flow is designed in unblocked manner.

# %%
# %%time

fav = fav.post(f'{server_url}/upscale')
fav.display()

# %% [markdown]
# > 💁‍♂️ On Google colab this image may render exactly the same size as before. But it is in 1024x1024 already. Right click on the image and copy/save it. You will see.
#
# That's it! It is _the one_. If not satisfied, please repeat the procedure. Btw, DocArray is a powerful and easy-to-use data structure for unstructured data. It is super productive for data scientists who work in cross-/multi-modal domain. To learn more about DocArray, [please check out the docs](https://docarray.jina.ai).
